# %%
people = {
    "first" : ["Corey", "Jane", "John"],
    "last" : ["Schafer", "Doe", "Doe"],
    "email" : ["CoreyMSchafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# ## df.colums에 직접 접근해서 columms을 update하기 1

# %%
df.columns = ['first_name', "last_name", "email"]

# %%
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %% [markdown]
# ## df.colums에 직접 접근해서 columms을 update하기 2

# %% [markdown]
# ### comprehension을 사용해서 각 column을 대문자로 update로 하기

# %%
df.columns = [x.upper() for x in df.columns]
df
# Out:
#    FIRST     LAST                    EMAIL
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
df.columns = df.columns.str.replace('_', ' ')
df
# Out:
#    FIRST     LAST                    EMAIL
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %% [markdown]
# ## rename을 사용해서 columns을 변경하기

# %%
df.rename(columns={'first_name': 'first', 'last_name':'last'}, inplace=True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %% [markdown]
# ## row를 변경하기 (loc, at)

# %%
df.loc[2] = ['John', 'Smith', 'JohnSmith@gmail.com']
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John    Smith      JohnSmith@gmail.com

# %%
df.loc[2, ['last', 'email']] = ['Doe', 'JohnDoe@email.com']
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2, 'last'] = 'Smith'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John    Smith        JohnDoe@email.com

# %%
df.at[2, 'last'] = 'Doe'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@email.com

# %% [markdown]
# ## Filtering을 사용해서 rows를 변경하기

# %%
df.loc[(df['email'] == "JohnDoe@email.com")['last']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-92c45c1c2b1b> in <module>
# ----> 1 df.loc[(df['email'] == "JohnDoe@email.com")['last']]
#
# ~/anaconda3/envs/stock/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~/anaconda3/envs/stock/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~/anaconda3/envs/stock/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
# ...

# %%
filt = (df['email'] == "JohnDoe@email.com")
df[filt]['last']
# Out:
# 2    Doe
# Name: last, dtype: object

# %%
df[df['email'] == "JohnDoe@email.com"]['last']
# Out:
# 2    Doe
# Name: last, dtype: object

# %%
df.loc[df['email'] == "JohnDoe@email.com"]['last']
# Out:
# 2    Doe
# Name: last, dtype: object

# %%
df.loc[df['email'] == "JohnDoe@email.com", 'last']
# Out:
# 2    Doe
# Name: last, dtype: object

# %%
df.loc[df['email'] == "JohnDoe@email.com", ['last']]
# Out:
#   last
# 2  Doe

# %%
df[df['email'] == "JohnDoe@email.com"]['last'] = 'Smith'
# Out:
# <ipython-input-38-85cd776d0acc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['email'] == "JohnDoe@email.com"]['last'] = 'Smith'

# %%
df[df['email'] == "JohnDoe@email.com", 'last'] = 'Smith'
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-15628ba32172> in <module>
# ----> 1 df[df['email'] == "JohnDoe@email.com", 'last'] = 'Smith'
#       2 df
#
# ~/anaconda3/envs/stock/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~/anaconda3/envs/stock/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~/anaconda3/envs/stock/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
# ...

# %%
df.loc[df['email'] == "JohnDoe@email.com", 'last'] = 'John'
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John     John        JohnDoe@email.com

# %%
df.loc[df['email'] == "JohnDoe@email.com"]['last'] = 'Smith'
df
# Out:
# <ipython-input-45-0719eb321cab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['email'] == "JohnDoe@email.com"]['last'] = 'Smith'
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John     John        JohnDoe@email.com

# %% [markdown]
# ## 1개의 column 데이터를 전부 바꾸기 series.str

# %%
df['email'] = df['email'].str.lower()
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@gmail.com
# 2   John     John        johndoe@email.com

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %% [markdown]
# ## 1개의 column 데이터를 전부 바꾸기 apply

# %%
df['email'] = df['email'].apply(update_email)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   Jane      Doe        JANEDOE@GMAIL.COM
# 2   John     John        JOHNDOE@EMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower())
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@gmail.com
# 2   John     John        johndoe@email.com

# %%
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %% [markdown]
# ## apply를 사용해서 rows, columns 형태로 여러 가지 적용하기

# %%
df.apply(len, axis="rows")
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df.apply(len, axis="columns")
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df.apply(pd.Series.max)
# Out:
# first                 John
# last               Schafer
# email    johndoe@email.com
# dtype: object

# %% [markdown]
# applymap is for Dataframe

# %% [markdown]
# ## applymap을 사용하면 전체에 적용할 수 있다.

# %%
df.applymap(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     4     17

# %%
df.applymap(str.lower)
# Out:
#    first     last                    email
# 0  corey  schafer  coreymschafer@gmail.com
# 1   jane      doe        janedoe@gmail.com
# 2   john     john        johndoe@email.com

# %% [markdown]
# map is for series

# %% [markdown]
# ## df.replace를 사용하면 전체 값을 바꿀 수 있다.

# %%
df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)

# %% [markdown]
# ## map과 dictionary를 사용해서 값을 바꾸기

# %%
df['first'].map({'Corey':'Chris', 'Jane':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %% [markdown]
# ## replace와 dictonary를 사용해서 값을 바꾸기

# %%
df['first'] = df['first'].replace({'Corey':'Chris', 'Jane':'Mary'})
df
# Out:
#    first     last                    email
# 0  Chris  Schafer  coreymschafer@gmail.com
# 1   Mary      Doe        janedoe@gmail.com
# 2   John     John        johndoe@email.com

# %% [markdown]
# ### ★ map을 사용하면, dictionary에 적용되지 않은 값은 NaN값이 된다.
# ### ★ replace를 사용하면, dictonary에 적용되지 않은 값은 그대로다.

# %%
df = pd.read_csv('~/Downloads/survey_results_public.csv')
schema_df = pd.read_csv('~/Downloads/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.rename(columns={'ConvertedComp' : 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %% [markdown]
# ## map과 dictonary를 사용해서 값을 변경하기

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes' : True, 'No' : False})

# %%
df
# Out:
#        Respondent                                         MainBranch  \
# 0               1             I am a student who is learning to code
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 88878       88377                                                NaN
# 88879       88601                                                NaN
# 88880       88802                                                NaN
# 88881       88816                                                NaN
# 88882       88863                                                NaN
#
#        Hobbyist                                        OpenSourcer  \
# 0          True                                              Never
# ...

# %% [markdown]
# map(나머지는 nan으로 만듬) vs replace (나머지는 그대로 둠)
